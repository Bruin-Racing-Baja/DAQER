# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#df = pd.read_csv("log_2025-11-21_23-39-42.csv")
timestamps = df["timestamp"].values

dt = np.diff(timestamps)

dt = dt / 1e6  

freq = 1 / dt

print("Min Frequency (Hz):", np.min(freq))
print("Max Frequency (Hz):", np.max(freq))
print("Mean Frequency (Hz):", np.mean(freq))
print("Median Frequency (Hz):", np.median(freq))


t = df["timestamp"]
ax = df["ax"]
ay = df["ay"]
az = df["az"]

plt.figure()
plt.plot(t, ax, label="ax")
plt.plot(t, ay, label="ay")
plt.plot(t, az, label="az")

plt.xlabel("Timestamp")
plt.ylabel("Acceleration")
plt.legend()
plt.show()
# Out:
# Min Frequency (Hz): 69.7350069735007
# Max Frequency (Hz): 420.87542087542084
# Mean Frequency (Hz): 130.12820814375343
# Median Frequency (Hz): 91.28251939753538
